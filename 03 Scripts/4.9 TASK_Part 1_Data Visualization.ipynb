# %% [markdown]
# # 1.1 - 1.3

# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %%
# Create path

path = r'G:\My Drive\CareerFoundry\Python Projects\2023-10 Instacart Basket Analysis'

# %%
# Imports customers data set
customers = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'customers.csv'), index_col = False)

# %% [markdown]
# # 1.4 Wrangle the data

# %%
# Get basic idea of data

customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206209 entries, 0 to 206208
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   user_id       206209 non-null  int64
#  1   First Name    194950 non-null  object
#  2   Surnam        206209 non-null  object
#  3   Gender        206209 non-null  object
#  4   STATE         206209 non-null  object
#  5   Age           206209 non-null  int64
#  6   date_joined   206209 non-null  object
#  7   n_dependants  206209 non-null  int64
#  8   fam_status    206209 non-null  object
#  9   income        206209 non-null  int64
# dtypes: int64(4), object(6)
# memory usage: 15.7+ MB

# %%
customers.head()
# Out:
#    user_id First Name    Surnam  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %%
# list of dtypes to include

include = ['object', 'float', 'int']

# %%
customers.describe(include=include)
# Out:
#               user_id First Name    Surnam  Gender    STATE            Age  \
# count   206209.000000     194950    206209  206209   206209  206209.000000
# unique            NaN        207      1000       2       51            NaN
# top               NaN    Marilyn  Hamilton    Male  Florida            NaN
# freq              NaN       2213       252  104067     4044            NaN
# mean    103105.000000        NaN       NaN     NaN      NaN      49.501646
# std      59527.555167        NaN       NaN     NaN      NaN      18.480962
# min          1.000000        NaN       NaN     NaN      NaN      18.000000
# 25%      51553.000000        NaN       NaN     NaN      NaN      33.000000
# 50%     103105.000000        NaN       NaN     NaN      NaN      49.000000
# 75%     154657.000000        NaN       NaN     NaN      NaN      66.000000
# max     206209.000000        NaN       NaN     NaN      NaN      81.000000
#
#        date_joined   n_dependants fam_status         income
# count       206209  206209.000000     206209  206209.000000
# unique        1187            NaN          4            NaN
# top      9/17/2018            NaN    married            NaN
# freq           213            NaN     144906            NaN
# mean           NaN       1.499823        NaN   94632.852548
# std            NaN       1.118433        NaN   42473.786988
# min            NaN       0.000000        NaN   25903.000000
# 25%            NaN       0.000000        NaN   59874.000000
# 50%            NaN       1.000000        NaN   93547.000000
# 75%            NaN       3.000000        NaN  124244.000000
# max            NaN       3.000000        NaN  593901.000000

# %%
# Drop date_joined col. - unnecessary to analysis parameters

ic_customers = customers.drop('date_joined', axis=1)

# %%
ic_customers.head()
# Out:
#    user_id First Name    Surnam  Gender       STATE  Age  n_dependants  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48             3
# 1    33890   Patricia      Hart  Female  New Mexico   36             0
# 2    65803    Kenneth    Farley    Male       Idaho   35             2
# 3   125935   Michelle     Hicks  Female        Iowa   40             0
# 4   130797        Ann   Gilmore  Female    Maryland   26             1
#
#   fam_status  income
# 0    married  165665
# 1     single   59285
# 2    married   99568
# 3     single   42049
# 4    married   40374

# %%
# Rename First Name, Surnam, Gender, State, Age and n_dependants for clarity and consistency

ic_customers.rename(columns = {'First Name' : 'first_name', 'Surnam' : 'last_name', 'Gender' : 'gender', 'STATE' : 'state', 'Age' : 'age', 'n_dependants' : 'dependants'}, inplace = True)

# %%
# Check result

ic_customers.columns
# Out:
# Index(['user_id', 'first_name', 'last_name', 'gender', 'state', 'age',
#        'dependants', 'fam_status', 'income'],
#       dtype='object')

# %% [markdown]
# # 1.5 Fundamental data quality and consistency checks

# %%
# Dtypes - change user_id to object ('str')

ic_customers[['user_id']] = ic_customers[['user_id']].astype(str)

# %%
ic_customers.dtypes
# Out:
# user_id       object
# first_name    object
# last_name     object
# gender        object
# state         object
# age            int64
# dependants     int64
# fam_status    object
# income         int64
# dtype: object

# %%
# Check for mixed-type columns

for col in ic_customers.columns.tolist():
  weird = (ic_customers[[col]].applymap(type) != ic_customers[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (ic_customers[weird]) > 0:
    print (col)
# Out:
# first_name

# %%
# Instead of fixing the mixed-type first_name column I will remove it and the last_name column. Neither is needed for this ad-hoc analysis.

ic_customers = ic_customers.drop(['first_name', 'last_name'], axis=1)

# %%
ic_customers.columns
# Out:
# Index(['user_id', 'gender', 'state', 'age', 'dependants', 'fam_status',
#        'income'],
#       dtype='object')

# %%
# Check for/confirm missing values (info() showed only first_name had missing values)

ic_customers.isnull().sum()
# Out:
# user_id       0
# gender        0
# state         0
# age           0
# dependants    0
# fam_status    0
# income        0
# dtype: int64

# %%
# Check for duplicates of entire df

ic_customers_dups = ic_customers[ic_customers.duplicated()]

# %%
ic_customers_dups
# Out:
# Empty DataFrame
# Columns: [user_id, gender, state, age, dependants, fam_status, income]
# Index: []

# %%
# NO DUPS

# %%
ic_customers.head()
# Out:
#   user_id  gender       state  age  dependants fam_status  income
# 0   26711  Female    Missouri   48           3    married  165665
# 1   33890  Female  New Mexico   36           0     single   59285
# 2   65803    Male       Idaho   35           2    married   99568
# 3  125935  Female        Iowa   40           0     single   42049
# 4  130797  Female    Maryland   26           1    married   40374

# %%
# Confirm unique values in state, fam_status and income are logical

# %%
ic_customers.describe(include=include)
# Out:
#        user_id  gender    state            age     dependants fam_status  \
# count   206209  206209   206209  206209.000000  206209.000000     206209
# unique  206209       2       51            NaN            NaN          4
# top      26711    Male  Florida            NaN            NaN    married
# freq         1  104067     4044            NaN            NaN     144906
# mean       NaN     NaN      NaN      49.501646       1.499823        NaN
# std        NaN     NaN      NaN      18.480962       1.118433        NaN
# min        NaN     NaN      NaN      18.000000       0.000000        NaN
# 25%        NaN     NaN      NaN      33.000000       0.000000        NaN
# 50%        NaN     NaN      NaN      49.000000       1.000000        NaN
# 75%        NaN     NaN      NaN      66.000000       3.000000        NaN
# max        NaN     NaN      NaN      81.000000       3.000000        NaN
#
#                income
# count   206209.000000
# unique            NaN
# top               NaN
# freq              NaN
# mean     94632.852548
# std      42473.786988
# min      25903.000000
# 25%      59874.000000
# 50%      93547.000000
# 75%     124244.000000
# max     593901.000000

# %%
print(ic_customers['state'].unique())
# Out:
# ['Missouri' 'New Mexico' 'Idaho' 'Iowa' 'Maryland' 'Kentucky' 'Montana'
#  'South Carolina' 'Texas' 'Virginia' 'Nevada' 'Nebraska' 'Georgia'
#  'Wyoming' 'Colorado' 'North Dakota' 'Wisconsin' 'Alaska' 'Vermont'
#  'Arkansas' 'Maine' 'North Carolina' 'West Virginia' 'Indiana' 'Oregon'
#  'Florida' 'California' 'Pennsylvania' 'Ohio' 'Connecticut' 'Arizona'
#  'Louisiana' 'Washington' 'New York' 'Mississippi' 'Oklahoma' 'Utah'
#  'New Hampshire' 'Hawaii' 'District of Columbia' 'Alabama' 'Massachusetts'
#  'Rhode Island' 'Michigan' 'New Jersey' 'Kansas' 'South Dakota'
#  'Minnesota' 'Illinois' 'Tennessee' 'Delaware']

# %%
print(ic_customers['fam_status'].unique())
# Out:
# ['married' 'single' 'living with parents and siblings' 'divorced/widowed']

# %%
# Max income seems high, check to see how many values are greater than the Q3 threshold

(ic_customers['income'] > 124244).sum()
# Out:
# 51551

# %%
# Too many instances to remove - confer with data source owners

# %% [markdown]
# # 1.6 Combine your customer data with the rest of your prepared Instacart data

# %%
# Import ords_prods_merge_grp_agg to combine with ic_customers

ords_prods = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merge_grp_agg.pkl'))

# %%
ords_prods.head()
# Out:
#    order_id  user_id  number_of_orders  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1                 1                   2                  8
# 1   2398795        1                 2                   3                  7
# 2    473747        1                 3                   3                 12
# 3   2254736        1                 4                   4                  7
# 4    431534        1                 5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     0.0         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  ...    price_range_loc     busiest_day     busiest_days  \
# 0         Soda  ...  Mid-range product  Regularly busy   Regularly busy
# 1         Soda  ...  Mid-range product  Regularly busy  Least busy days
# 2         Soda  ...  Mid-range product  Regularly busy  Least busy days
# 3         Soda  ...  Mid-range product      Least busy  Least busy days
# 4         Soda  ...  Mid-range product      Least busy  Least busy days
#
#   busiest_period_of_day max_order  loyalty_flag avg_item_price spending_flag  \
# 0        Average orders        10  New customer       6.367797   Low spender
# 1        Average orders        10  New customer       6.367797   Low spender
# 2           Most orders        10  New customer       6.367797   Low spender
# 3        Average orders        10  New customer       6.367797   Low spender
# 4           Most orders        10  New customer       6.367797   Low spender
#
#    prior_order_median   order_freq_flag
# 0                20.0  Regular customer
# 1                20.0  Regular customer
# 2                20.0  Regular customer
# 3                20.0  Regular customer
# 4                20.0  Regular customer
#
# [5 rows x 24 columns]

# %%
ords_prods.columns
# Out:
# Index(['order_id', 'user_id', 'number_of_orders', 'orders_day_of_week',
#        'order_hour_of_day', 'days_since_prior_order', 'product_id',
#        'add_to_cart_order', 'reordered', 'product_name', 'aisle_id',
#        'department_id', 'prices', '_merge', 'price_range_loc', 'busiest_day',
#        'busiest_days', 'busiest_period_of_day', 'max_order', 'loyalty_flag',
#        'avg_item_price', 'spending_flag', 'prior_order_median',
#        'order_freq_flag'],
#       dtype='object')

# %%
# Remove unneeded columns

ords_prods_merge = ords_prods.drop(['_merge', 'busiest_day', 'max_order', 'avg_item_price', 'prior_order_median'], axis=1)

# %%
ords_prods_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32404859 entries, 0 to 32404858
# Data columns (total 19 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int64
#  1   user_id                 int64
#  2   number_of_orders        int64
#  3   orders_day_of_week      int64
#  4   order_hour_of_day       int64
#  5   days_since_prior_order  float64
#  6   product_id              int64
#  7   add_to_cart_order       int64
#  8   reordered               int64
#  9   product_name            object
#  10  aisle_id                int64
#  11  department_id           int64
#  12  prices                  float64
#  13  price_range_loc         object
#  14  busiest_days            object
#  15  busiest_period_of_day   object
#  16  loyalty_flag            object
#  17  spending_flag           object
#  18  order_freq_flag         object
# dtypes: float64(2), int64(10), object(7)
# memory usage: 4.6+ GB

# %%
del ords_prods

# %%
# Change ords_prods_merge 'user_id' dtype to object to match 'user_id' in ic_customers

ords_prods_merge[['user_id']] = ords_prods_merge[['user_id']].astype(str)

# %%
ords_prods_merge['user_id'].dtype
# Out:
# dtype('O')

# %%
ords_prods_merge.describe(include=include)

# %%
# Use Inner Join to merge but first test merge without overwriting

pd.merge(ic_customers,ords_prods_merge, on = ['user_id'], indicator = True)
# Out:
#          user_id  gender     state  age  dependants fam_status  income  \
# 0          26711  Female  Missouri   48           3    married  165665
# 1          26711  Female  Missouri   48           3    married  165665
# 2          26711  Female  Missouri   48           3    married  165665
# 3          26711  Female  Missouri   48           3    married  165665
# 4          26711  Female  Missouri   48           3    married  165665
# ...          ...     ...       ...  ...         ...        ...     ...
# 32404854   80148  Female  New York   55           1    married   57095
# 32404855   80148  Female  New York   55           1    married   57095
# 32404856   80148  Female  New York   55           1    married   57095
# 32404857   80148  Female  New York   55           1    married   57095
# 32404858   80148  Female  New York   55           1    married   57095
#
#           order_id  number_of_orders  orders_day_of_week  ...  aisle_id  \
# 0          2543867                 5                   1  ...        77
# 1          1285508                 7                   5  ...        77
# 2          2578584                 8                   1  ...        77
# 3           423547                 2                   2  ...       120
# 4          2524893                 3                   3  ...       120
# ...            ...               ...                 ...  ...       ...
# 32404854   2859858                 3                   6  ...         3
# 32404855   2859858                 3                   6  ...         3
# 32404856   3209855                 4                   6  ...        26
# 32404857   2859858                 3                   6  ...         3
# 32404858   2859858                 3                   6  ...         3
#
#           department_id  prices    price_range_loc     busiest_days  \
# 0                     7     9.0  Mid-range product     Busiest days
# 1                     7     9.0  Mid-range product   Regularly busy
# 2                     7     9.0  Mid-range product     Busiest days
# 3                    16    12.6  Mid-range product   Regularly busy
# 4                    16    12.6  Mid-range product  Least busy days
# ...                 ...     ...                ...              ...
# 32404854             19     4.7  Low-range product   Regularly busy
# 32404855             19     4.0  Low-range product   Regularly busy
# 32404856              7     4.7  Low-range product   Regularly busy
# 32404857             19     1.8  Low-range product   Regularly busy
# 32404858             19     6.0  Mid-range product   Regularly busy
#
#          busiest_period_of_day  loyalty_flag  spending_flag   order_freq_flag  \
# 0                  Most orders  New customer    Low spender  Regular customer
# 1                  Most orders  New customer    Low spender  Regular customer
# 2                  Most orders  New customer    Low spender  Regular customer
# 3                  Most orders  New customer    Low spender  Regular customer
# 4                  Most orders  New customer    Low spender  Regular customer
# ...                        ...           ...            ...               ...
# 32404854           Most orders  New customer    Low spender  Regular customer
# 32404855           Most orders  New customer    Low spender  Regular customer
# 32404856        Average orders  New customer    Low spender  Regular customer
# 32404857           Most orders  New customer    Low spender  Regular customer
# 32404858           Most orders  New customer    Low spender  Regular customer
#
#          _merge
# 0          both
# 1          both
# 2          both
# 3          both
# 4          both
# ...         ...
# 32404854   both
# 32404855   both
# 32404856   both
# 32404857   both
# 32404858   both
#
# [32404859 rows x 26 columns]

# %%
# Merge

ords_prods_cust_merged = ords_prods_merge.merge(ic_customers, on = 'user_id')

# %%
ords_prods_cust_merged.head()
# Out:
#    order_id user_id  number_of_orders  orders_day_of_week  order_hour_of_day  \
# 0   2539329       1                 1                   2                  8
# 1   2398795       1                 2                   3                  7
# 2    473747       1                 3                   3                 12
# 3   2254736       1                 4                   4                  7
# 4    431534       1                 5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     0.0         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  ...  busiest_period_of_day  loyalty_flag  spending_flag  \
# 0         Soda  ...         Average orders  New customer    Low spender
# 1         Soda  ...         Average orders  New customer    Low spender
# 2         Soda  ...            Most orders  New customer    Low spender
# 3         Soda  ...         Average orders  New customer    Low spender
# 4         Soda  ...            Most orders  New customer    Low spender
#
#     order_freq_flag  gender    state age dependants fam_status income
# 0  Regular customer  Female  Alabama  31          3    married  40423
# 1  Regular customer  Female  Alabama  31          3    married  40423
# 2  Regular customer  Female  Alabama  31          3    married  40423
# 3  Regular customer  Female  Alabama  31          3    married  40423
# 4  Regular customer  Female  Alabama  31          3    married  40423
#
# [5 rows x 25 columns]

# %%
ords_prods_cust_merged.shape
# Out:
# (32404859, 25)

# %%
# Export new df as pkl

ords_prods_cust_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'ords_prods_cust_merged.pkl'))
